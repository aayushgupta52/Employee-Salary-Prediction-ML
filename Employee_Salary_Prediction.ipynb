# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushgupta52/Employee-Salary-Prediction-ML/blob/main/Employee_Salary_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_excel("/content/Employees.xlsx")

# %%
data.head(3)
# Out:
#    No First Name Last Name  ... Sick Leaves Unpaid Leaves  Overtime Hours
# 0   1     Ghadir     Hmshw  ...           1             0             183
# 1   2       Omar    Hishan  ...           0             5             198
# 2   3      Ailya    Sharaf  ...           0             3             192
#
# [3 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              689 non-null    int64
#  1   First Name      689 non-null    object
#  2   Last Name       689 non-null    object
#  3   Gender          689 non-null    object
#  4   Start Date      689 non-null    datetime64[ns]
#  5   Years           689 non-null    int64
#  6   Department      689 non-null    object
#  7   Country         689 non-null    object
#  8   Center          689 non-null    object
#  9   Monthly Salary  689 non-null    int64
#  10  Annual Salary   689 non-null    int64
#  11  Job Rate        689 non-null    float64
#  12  Sick Leaves     689 non-null    int64
#  13  Unpaid Leaves   689 non-null    int64
#  14  Overtime Hours  689 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(6)
# memory usage: 80.9+ KB

# %%
data.shape
# Out:
# (689, 15)

# %%
data.isna().sum()
# Out:
# No                0
# First Name        0
# Last Name         0
# Gender            0
# Start Date        0
# Years             0
# Department        0
# Country           0
# Center            0
# Monthly Salary    0
# Annual Salary     0
# Job Rate          0
# Sick Leaves       0
# Unpaid Leaves     0
# Overtime Hours    0
# dtype: int64

# %%
#data.dropna(inplace=True) For dropping NA values in the dataset

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#data.drop_duplicate(inplace = True) for dropping duplicates

# %%
data.head(3)
# Out:
#    No First Name Last Name  ... Sick Leaves Unpaid Leaves  Overtime Hours
# 0   1     Ghadir     Hmshw  ...           1             0             183
# 1   2       Omar    Hishan  ...           0             5             198
# 2   3      Ailya    Sharaf  ...           0             3             192
#
# [3 rows x 15 columns]

# %%
data["Gender"].value_counts().sort_values(ascending=False).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
data.head(2)
# Out:
#    No First Name Last Name  ... Sick Leaves Unpaid Leaves  Overtime Hours
# 0   1     Ghadir     Hmshw  ...           1             0             183
# 1   2       Omar    Hishan  ...           0             5             198
#
# [2 rows x 15 columns]

# %%
plt.hist(data["Job Rate"])
plt.title("Histogram of Job Rates")
plt.xlabel("Job Rate")
plt.ylabel("Count")
plt.show()

# %%
data["Job Rate"].describe()
# Out:
# count    689.000000
# mean       3.586357
# std        1.350125
# min        1.000000
# 25%        3.000000
# 50%        3.000000
# 75%        5.000000
# max        5.000000
# Name: Job Rate, dtype: float64

# %%
data.groupby("Department")["Annual Salary"].mean().sort_values(ascending=False).head(7).plot(kind="bar")
plt.title("Average  Salary by Department")
plt.xlabel("Department")
plt.ylabel("Average  Salary")
plt.show()

# %%
data.groupby("Center")["Monthly Salary"].mean().sort_values(ascending=False)
# Out:
# Center
# East     2274.021277
# West     2068.672269
# North    2064.811594
# Main     2054.776892
# South    1981.153846
# Name: Monthly Salary, dtype: float64

# %%
data["Country"].unique()
# Out:
# array(['Egypt', 'Saudi Arabia', 'United Arab Emirates', 'Syria',
#        'Lebanon'], dtype=object)

# %%
plt.hist(data["Overtime Hours"])
plt.title("Histogram of Overtime Hours")
plt.xlabel("Overtime Hours")
plt.ylabel("Count")
plt.show()

# %%
data["Overtime Hours"].describe()
# Out:
# count    689.000000
# mean      13.702467
# std       25.692049
# min        0.000000
# 25%        3.000000
# 50%        7.000000
# 75%       10.000000
# max      198.000000
# Name: Overtime Hours, dtype: float64

# %%
data
# Out:
#       No   First Name Last Name  ... Sick Leaves Unpaid Leaves  Overtime Hours
# 0      1       Ghadir     Hmshw  ...           1             0             183
# 1      2         Omar    Hishan  ...           0             5             198
# 2      3        Ailya    Sharaf  ...           0             3             192
# 3      4         Lwiy     Qbany  ...           0             0               7
# 4      5        Ahmad     Bikri  ...           0             5             121
# ..   ...          ...       ...  ...         ...           ...             ...
# 684  685         Sari     Hanna  ...           0             3               1
# 685  686      Eubayda      Kayd  ...           1             0               4
# 686  687       Khalil    Alkalu  ...           0             0               0
# 687  688      Muhamad    Shrbjy  ...           0             0              10
# 688  689  Abd Albasit   AlAhmar  ...           0             0               0
#
# [689 rows x 15 columns]

# %%
data['Annual Salary'].describe()
# Out:
# count      689.000000
# mean     24818.420900
# std       9159.470878
# min       8436.000000
# 25%      17232.000000
# 50%      24924.000000
# 75%      32184.000000
# max      41400.000000
# Name: Annual Salary, dtype: float64

# %%
data
# Out:
#       No   First Name Last Name  ... Sick Leaves Unpaid Leaves  Overtime Hours
# 0      1       Ghadir     Hmshw  ...           1             0             183
# 1      2         Omar    Hishan  ...           0             5             198
# 2      3        Ailya    Sharaf  ...           0             3             192
# 3      4         Lwiy     Qbany  ...           0             0               7
# 4      5        Ahmad     Bikri  ...           0             5             121
# ..   ...          ...       ...  ...         ...           ...             ...
# 684  685         Sari     Hanna  ...           0             3               1
# 685  686      Eubayda      Kayd  ...           1             0               4
# 686  687       Khalil    Alkalu  ...           0             0               0
# 687  688      Muhamad    Shrbjy  ...           0             0              10
# 688  689  Abd Albasit   AlAhmar  ...           0             0               0
#
# [689 rows x 15 columns]

# %%
data.columns
# Out:
# Index(['No', 'First Name', 'Last Name', 'Gender', 'Start Date', 'Years',
#        'Department', 'Country', 'Center', 'Monthly Salary', 'Annual Salary',
#        'Job Rate', 'Sick Leaves', 'Unpaid Leaves', 'Overtime Hours'],
#       dtype='object')

# %%
x =data[["Years","Job Rate"]]
y = data["Annual Salary"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
len(y_train)
# Out:
# 551

# %%
len(X_test)
# Out:
# 138

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predslr= lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,predslr)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,predslr)
# Out:
# 7511.403175836677

# %%
import joblib
joblib.dump(lr,"linearmodel.pkl")
# Out:
# ['linearmodel.pkl']
